# %% [markdown]
# # Gitlab CI/CD
#
# Reference:
#
# https://www.youtube.com/watch?v=jUiKi6FWYrg
#
# Project used:
#
# for later [kubes, docker etc] - very good!
# ```
# https://www.youtube.com/c/TechWorldwithNana/playlists
#
# ```

# %% [markdown]
# CI cover the folling
# - Dev
# - Applcation Testing
# - Integration Testing
#
# All of the above jobs are trigger and automated.
#
# When er add
# - Acceptance test
#
# We get CDelivery, which means ap is ready for delivery.
#
# And wehn we add,
# - Production (deployenent)
#
# We get CDeploment
#
#
# All of the jobs are chained and can be automatically triggered.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Gitab CI, which is open source is include in every version of gitlab (v8 and above).
#
# To create a gitlab CI CD pipe line, we will need to create a ```.gitlab-ci.yml``` file. This file in created in root folder of the project/repo
#
# ```.gitlab-ci.yml``` is used to create a pipeline.
#
#
#
#
# #### create yml file
#
# 1. Give the name of job -  demo_job_1 and add a colon
# ```
#
# ```
#
#
#
# ## creating the project
# 1. Create the project on gitlab
# 2. Then use the following to create project on local, We use this approach(and not the approach where we create a folder, since we also running github on machine). This approach allows us to specify the username and password)
#
# ```
# git clone https://gitlab.com/expansity/gitlabdemo.git
# cd gitlabdemo
# touch README.md
# git add README.md
# git commit -m "add README"
# git push -u origin master
# ```
# (And do this in the [projects folder)
#
# ```
# git branch
# ```
#
# They still using master.
